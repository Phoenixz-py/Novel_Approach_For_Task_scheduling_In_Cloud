# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
random.seed(42)

# %%
class Task:
    next_id = 0
    # Define parameters for the Poisson distribution
    mean_arrival_rate = 1  # Adjust this value as needed


    def __init__(self,arrival_time):
        self.id = Task.next_id
        self.arrival_time = arrival_time
        self.length = random.choice([100,200,300])
        self.deadline = arrival_time + random.randint(1,5)
        Task.next_id += 1

    def __str__(self):
        return "Task " + str(self.id)

    def __repr__(self):
        return "Task " + str(self.id)

    @classmethod
    def create_tasks(cls, n):
        # Generate arrival times using Poisson distribution
        arrival_times = np.sort(np.random.poisson(Task.mean_arrival_rate, n)).astype(int).tolist()
        tasks = [cls(arrival_times[i]) for i in range(n)]
        return tasks

# %%
class VM:
    next_id = 0

    def __init__(self):
        self.id = VM.next_id
        VM.next_id += 1
        self.mips = random.choice([20,30])

    def __str__(self):
        return f"VM {self.id}"

    def __repr__(self):
        return f"VM {self.id}"

    @classmethod
    def create_vms(cls, n):
        vms = [cls() for _ in range(n)]
        return vms

# %%
def objective_function(solution):
    vm_completion_times = {vm: 0 for _,vm in solution.items()}
    tasks_on_time = 0
    for task, assigned_vm in solution.items():
        task_length = task.length
        vm = assigned_vm
        # Start time considering VM's completion time or task's arrival time
        start_time = max(vm_completion_times[vm], task.arrival_time)
        completion_time = start_time + task_length/vm.mips

        if task.deadline:
          delay = max(0, completion_time - task.deadline)
          if delay == 0:
            tasks_on_time += 1

        vm_completion_times[vm] = completion_time
    success_ratio = tasks_on_time/len(solution)
    fitness = max(vm_completion_times.values())

    return fitness

# %%
def initialize_population(pop_size,tasks,vms):
    population = []
    population_set = set()
    while len(population) < pop_size:
      solution = {task: random.choice(vms) for task in tasks}
      # Convert the solution dictionary to a frozenset to make it hashable
      solution_frozenset = frozenset(solution.items())
      if solution_frozenset not in population_set:
        # This solution is unique, add it to the population
        population.append(solution)
        population_set.add(solution_frozenset)
    return population

# %%
n_tasks = 3
n_vms = 2


# Usage example
tasks_list = Task.create_tasks(n_tasks) # Task set
vms_list = VM.create_vms(n_vms) # VM set

# %%
    # for j,particle in enumerate(swarm):
    #     print(f"Particle {j}")
    #     for task,vm in particle.items():
    #         print(f"{task}({task.arrival_time}) : {vm}  ,Execution Time  ({task.length}/{vm.mips}) = {task.length/vm.mips}")

# %%
for task in tasks_list:
    print(f"Task {task.id} ,Length = {task.length} arrived at {task.arrival_time}")
# Out:
# Task 0 ,Length = 300 arrived at 0
# Task 1 ,Length = 100 arrived at 0
# Task 2 ,Length = 100 arrived at 3

# %%
for vm in vms_list:
    print(f"VM {vm.id} , MIPS = {vm.mips}")
# Out:
# VM 0 , MIPS = 20
# VM 1 , MIPS = 20

# %%
def pso(tasks,vms,swarm_size,max_iter):

  # let us take
  # fitness is taken as makespan
  # position is taken as vm
  # velocity is taken as mips

  w = 0.7298
  c1 = 1.4962
  c2 = 1.4962


  swarm = initialize_population(swarm_size,tasks,vms)
  particle_personal_best = [objective_function(particle) for particle in swarm]
  # Initialize variables to store the global best fitness and the corresponding particle
  global_best_fitness = float('inf')  # Initialize with a high value
  global_best_particle = None

  makespan_history = []  # To store makespan values over iterations


  for i in range(max_iter):
    print(f"Starting Iteration {i} ,Now For Each Particle")
    if global_best_particle:
      print(f"Before Iteration {i}, Best Makespan = {global_best_fitness} is of Particle {swarm.index(global_best_particle)}")
      
    for j,particle in enumerate(swarm):
        print(f"Particle {j}")
        for task,vm in particle.items():
            print(f"{task}({task.arrival_time}) : {vm}  ,Execution Time  ({task.length}/{vm.mips}) = {task.length/vm.mips}")
        # Evaluate fitness of the current particle
        current_fitness = objective_function(particle)
        print("Current Fitness = ",current_fitness)
        print("Particle Personal Best = ",particle_personal_best[j])
        print("Global Best Fitness = ",global_best_fitness)
        
        # Update the personal best if needed
        if current_fitness < particle_personal_best[j]:
            print(f"Particle Personal Best Changed to {current_fitness}")
            particle_personal_best[j] = current_fitness

        # Update the global best if needed
        if current_fitness < global_best_fitness:
            print(f"Global Best Changed to {current_fitness}")
            global_best_fitness = current_fitness
            global_best_particle = particle


        # Update particle velocities and positions
        for task,_ in particle.items():
            print("For",task)
            r1 = random.random()
            r2 = random.random()
            print(f"r1 = {r1} ,r2 = {r2}")
            # Get the current VM assigned to the task
            current_vm = particle[task]

            # Update the velocity for the task-VM assignment
            new_velocity = (w * task.length/current_vm.mips + c1 * r1 * (particle_personal_best[j] - current_fitness) +
                            c2 * r2 * (global_best_fitness - current_fitness))
            print(f"New Velocity = {w} * {task.length} / {current_vm.mips} + {c1} * {r1} * ({particle_personal_best[j]} - {current_fitness}) + {c2} * {r2} * ({global_best_fitness} - {current_fitness})")
            print("New Velocity = ",new_velocity)
            # Update the particle's assignment based on the new velocity
            # This step decides which VM the task will be assigned to
            if new_velocity > 0:
                # Assign the task to a different VM if the velocity is positive
                possible_vms = [vm for vm in vms if vm != current_vm]
                new_assigned_vm = random.choice(possible_vms)
                particle[task] = new_assigned_vm
                print(f'Since New Velocity Is Positive , New Assigned VM = {new_assigned_vm}')
            else:
                print(f'Since New Velocity Is Negative There is No Change')
            print()
        print()
    print(f"After Iteration {i}, Best Makespan = {global_best_fitness} is of Particle {swarm.index(global_best_particle)}")
    print()
    #     print(f"Evaluating for {len(tasks)} Tasks and {len(vms)} VMs... \n At Iteration {i + 1} - Best Makespan: {global_best_fitness}")
    # clear_output(wait=True)
    # Continue with the next iteration
    makespan_history.append(global_best_fitness)  # Collect makespan values
  return global_best_particle, global_best_fitness, makespan_history

# %%
# status is shown for before that iteration

# %%
swarm_size = 3
max_iter = 4
output = ""

makespan_histories_pso = []

best_solution, best_makespan, makespan_history = pso(tasks_list, vms_list, swarm_size,max_iter)

# print(f"Best Makespan = {best_makespan}")
# output +="For {} Tasks and {} VMs Best Makespan Is {}\n".format(n_tasks,n_vms,best_makespan)

# print(output)
# Out:
# Starting Iteration 0 ,Now For Each Particle
# Particle 0
# Task 0(0) : VM 1  ,Execution Time  (300/20) = 15.0
# Task 1(0) : VM 1  ,Execution Time  (100/20) = 5.0
# Task 2(3) : VM 1  ,Execution Time  (100/20) = 5.0
# Current Fitness =  25.0
# Particle Personal Best =  25.0
# Global Best Fitness =  inf
# Global Best Changed to 25.0
# For Task 0
# r1 = 0.09338720007556267 ,r2 = 0.9519996624524752
# New Velocity = 0.7298 * 300 / 20 + 1.4962 * 0.09338720007556267 * (25.0 - 25.0) + 1.4962 * 0.9519996624524752 * (25.0 - 25.0)
# New Velocity =  10.947
# Since New Velocity Is Positive , New Assigned VM = VM 0
#
# For Task 1
# r1 = 0.672795670557167 ,r2 = 0.22464066599728827
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.672795670557167 * (25.0 - 25.0) + 1.4962 * 0.22464066599728827 * (25.0 - 25.0)
# New Velocity =  3.649
# Since New Velocity Is Positive , New Assigned VM = VM 0
#
# For Task 2
# r1 = 0.14735396224577268 ,r2 = 0.04621371809275843
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.14735396224577268 * (25.0 - 25.0) + 1.4962 * 0.04621371809275843 * (25.0 - 25.0)
# New Velocity =  3.649
# Since New Velocity Is Positive , New Assigned VM = VM 0
#
#
# Particle 1
# Task 0(0) : VM 0  ,Execution Time  (300/20) = 15.0
# Task 1(0) : VM 1  ,Execution Time  (100/20) = 5.0
# Task 2(3) : VM 0  ,Execution Time  (100/20) = 5.0
# Current Fitness =  20.0
# Particle Personal Best =  20.0
# Global Best Fitness =  25.0
# Global Best Changed to 20.0
# For Task 0
# r1 = 0.6112739730606801 ,r2 = 0.7684893390001969
# New Velocity = 0.7298 * 300 / 20 + 1.4962 * 0.6112739730606801 * (20.0 - 20.0) + 1.4962 * 0.7684893390001969 * (20.0 - 20.0)
# New Velocity =  10.947
# Since New Velocity Is Positive , New Assigned VM = VM 1
#
# For Task 1
# r1 = 0.41444101099771935 ,r2 = 0.6297653807377137
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.41444101099771935 * (20.0 - 20.0) + 1.4962 * 0.6297653807377137 * (20.0 - 20.0)
# New Velocity =  3.649
# Since New Velocity Is Positive , New Assigned VM = VM 0
#
# For Task 2
# r1 = 0.7183459154989886 ,r2 = 0.3839784673927513
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.7183459154989886 * (20.0 - 20.0) + 1.4962 * 0.3839784673927513 * (20.0 - 20.0)
# New Velocity =  3.649
# Since New Velocity Is Positive , New Assigned VM = VM 1
#
#
# Particle 2
# Task 0(0) : VM 0  ,Execution Time  (300/20) = 15.0
# Task 1(0) : VM 1  ,Execution Time  (100/20) = 5.0
# Task 2(3) : VM 1  ,Execution Time  (100/20) = 5.0
# Current Fitness =  15.0
# Particle Personal Best =  15.0
# Global Best Fitness =  20.0
# Global Best Changed to 15.0
# For Task 0
# r1 = 0.24398443957843885 ,r2 = 0.6560580111117841
# New Velocity = 0.7298 * 300 / 20 + 1.4962 * 0.24398443957843885 * (15.0 - 15.0) + 1.4962 * 0.6560580111117841 * (15.0 - 15.0)
# New Velocity =  10.947
# Since New Velocity Is Positive , New Assigned VM = VM 1
#
# For Task 1
# r1 = 0.8926598262113665 ,r2 = 0.8604405654225213
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.8926598262113665 * (15.0 - 15.0) + 1.4962 * 0.8604405654225213 * (15.0 - 15.0)
# New Velocity =  3.649
# Since New Velocity Is Positive , New Assigned VM = VM 0
#
# For Task 2
# r1 = 0.778420406767325 ,r2 = 0.21884113681231943
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.778420406767325 * (15.0 - 15.0) + 1.4962 * 0.21884113681231943 * (15.0 - 15.0)
# New Velocity =  3.649
# Since New Velocity Is Positive , New Assigned VM = VM 0
#
#
# After Iteration 0, Best Makespan = 15.0 is of Particle 2
#
# Starting Iteration 1 ,Now For Each Particle
# Before Iteration 1, Best Makespan = 15.0 is of Particle 2
# Particle 0
# Task 0(0) : VM 0  ,Execution Time  (300/20) = 15.0
# Task 1(0) : VM 0  ,Execution Time  (100/20) = 5.0
# Task 2(3) : VM 0  ,Execution Time  (100/20) = 5.0
# Current Fitness =  25.0
# Particle Personal Best =  25.0
# Global Best Fitness =  15.0
# For Task 0
# r1 = 0.05021838514064092 ,r2 = 0.24919827965997166
# New Velocity = 0.7298 * 300 / 20 + 1.4962 * 0.05021838514064092 * (25.0 - 25.0) + 1.4962 * 0.24919827965997166 * (15.0 - 25.0)
# New Velocity =  7.218495339727504
# Since New Velocity Is Positive , New Assigned VM = VM 1
#
# For Task 1
# r1 = 0.45646182547017256 ,r2 = 0.8014166017222645
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.45646182547017256 * (25.0 - 25.0) + 1.4962 * 0.8014166017222645 * (15.0 - 25.0)
# New Velocity =  -8.341795194968519
# Since New Velocity Is Negative There is No Change
#
# For Task 2
# r1 = 0.6675777325863531 ,r2 = 0.987892453066448
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.6675777325863531 * (25.0 - 25.0) + 1.4962 * 0.987892453066448 * (15.0 - 25.0)
# New Velocity =  -11.131846882780195
# Since New Velocity Is Negative There is No Change
#
#
# Particle 1
# Task 0(0) : VM 1  ,Execution Time  (300/20) = 15.0
# Task 1(0) : VM 0  ,Execution Time  (100/20) = 5.0
# Task 2(3) : VM 1  ,Execution Time  (100/20) = 5.0
# Current Fitness =  20.0
# Particle Personal Best =  20.0
# Global Best Fitness =  15.0
# For Task 0
# r1 = 0.5954523184694197 ,r2 = 0.9500396084431559
# New Velocity = 0.7298 * 300 / 20 + 1.4962 * 0.5954523184694197 * (20.0 - 20.0) + 1.4962 * 0.9500396084431559 * (15.0 - 20.0)
# New Velocity =  3.8397536892367494
# Since New Velocity Is Positive , New Assigned VM = VM 0
#
# For Task 1
# r1 = 0.6126523227617628 ,r2 = 0.7192739612759671
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.6126523227617628 * (20.0 - 20.0) + 1.4962 * 0.7192739612759671 * (15.0 - 20.0)
# New Velocity =  -1.73188850430551
# Since New Velocity Is Negative There is No Change
#
# For Task 2
# r1 = 0.504778164824402 ,r2 = 0.830569169721415
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.504778164824402 * (20.0 - 20.0) + 1.4962 * 0.830569169721415 * (15.0 - 20.0)
# New Velocity =  -2.5644879586859064
# Since New Velocity Is Negative There is No Change
#
#
# Particle 2
# Task 0(0) : VM 1  ,Execution Time  (300/20) = 15.0
# Task 1(0) : VM 0  ,Execution Time  (100/20) = 5.0
# Task 2(3) : VM 0  ,Execution Time  (100/20) = 5.0
# Current Fitness =  15.0
# Particle Personal Best =  15.0
# Global Best Fitness =  15.0
# For Task 0
# r1 = 0.5478719506108284 ,r2 = 0.8972081032332622
# New Velocity = 0.7298 * 300 / 20 + 1.4962 * 0.5478719506108284 * (15.0 - 15.0) + 1.4962 * 0.8972081032332622 * (15.0 - 15.0)
# New Velocity =  10.947
# Since New Velocity Is Positive , New Assigned VM = VM 0
#
# For Task 1
# r1 = 0.4500697572469081 ,r2 = 0.7517767865005115
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.4500697572469081 * (15.0 - 15.0) + 1.4962 * 0.7517767865005115 * (15.0 - 15.0)
# New Velocity =  3.649
# Since New Velocity Is Positive , New Assigned VM = VM 1
#
# For Task 2
# r1 = 0.7658136842971655 ,r2 = 0.5212998128279821
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.7658136842971655 * (15.0 - 15.0) + 1.4962 * 0.5212998128279821 * (15.0 - 15.0)
# New Velocity =  3.649
# Since New Velocity Is Positive , New Assigned VM = VM 1
#
#
# After Iteration 1, Best Makespan = 15.0 is of Particle 2
#
# Starting Iteration 2 ,Now For Each Particle
# Before Iteration 2, Best Makespan = 15.0 is of Particle 2
# Particle 0
# Task 0(0) : VM 1  ,Execution Time  (300/20) = 15.0
# Task 1(0) : VM 0  ,Execution Time  (100/20) = 5.0
# Task 2(3) : VM 0  ,Execution Time  (100/20) = 5.0
# Current Fitness =  15.0
# Particle Personal Best =  25.0
# Global Best Fitness =  15.0
# Particle Personal Best Changed to 15.0
# For Task 0
# r1 = 0.2745974469175383 ,r2 = 0.07748335386473582
# New Velocity = 0.7298 * 300 / 20 + 1.4962 * 0.2745974469175383 * (15.0 - 15.0) + 1.4962 * 0.07748335386473582 * (15.0 - 15.0)
# New Velocity =  10.947
# Since New Velocity Is Positive , New Assigned VM = VM 0
#
# For Task 1
# r1 = 0.23449357801463533 ,r2 = 0.33584753662131395
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.23449357801463533 * (15.0 - 15.0) + 1.4962 * 0.33584753662131395 * (15.0 - 15.0)
# New Velocity =  3.649
# Since New Velocity Is Positive , New Assigned VM = VM 1
#
# For Task 2
# r1 = 0.13837406151615572 ,r2 = 0.23126147972818678
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.13837406151615572 * (15.0 - 15.0) + 1.4962 * 0.23126147972818678 * (15.0 - 15.0)
# New Velocity =  3.649
# Since New Velocity Is Positive , New Assigned VM = VM 1
#
#
# Particle 1
# Task 0(0) : VM 0  ,Execution Time  (300/20) = 15.0
# Task 1(0) : VM 0  ,Execution Time  (100/20) = 5.0
# Task 2(3) : VM 1  ,Execution Time  (100/20) = 5.0
# Current Fitness =  20.0
# Particle Personal Best =  20.0
# Global Best Fitness =  15.0
# For Task 0
# r1 = 0.7064191416945522 ,r2 = 0.06422885071387807
# New Velocity = 0.7298 * 300 / 20 + 1.4962 * 0.7064191416945522 * (20.0 - 20.0) + 1.4962 * 0.06422885071387807 * (15.0 - 20.0)
# New Velocity =  10.466503967809476
# Since New Velocity Is Positive , New Assigned VM = VM 1
#
# For Task 1
# r1 = 0.33088139103808356 ,r2 = 0.46592430335115065
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.33088139103808356 * (20.0 - 20.0) + 1.4962 * 0.46592430335115065 * (15.0 - 20.0)
# New Velocity =  0.16342028663004227
# Since New Velocity Is Positive , New Assigned VM = VM 1
#
# For Task 2
# r1 = 0.20683438951441024 ,r2 = 0.4201435177734256
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.20683438951441024 * (20.0 - 20.0) + 1.4962 * 0.4201435177734256 * (15.0 - 20.0)
# New Velocity =  0.5059063435370033
# Since New Velocity Is Positive , New Assigned VM = VM 0
#
#
# Particle 2
# Task 0(0) : VM 0  ,Execution Time  (300/20) = 15.0
# Task 1(0) : VM 1  ,Execution Time  (100/20) = 5.0
# Task 2(3) : VM 1  ,Execution Time  (100/20) = 5.0
# Current Fitness =  15.0
# Particle Personal Best =  15.0
# Global Best Fitness =  15.0
# For Task 0
# r1 = 0.8567320323039342 ,r2 = 0.7655945761180695
# New Velocity = 0.7298 * 300 / 20 + 1.4962 * 0.8567320323039342 * (15.0 - 15.0) + 1.4962 * 0.7655945761180695 * (15.0 - 15.0)
# New Velocity =  10.947
# Since New Velocity Is Positive , New Assigned VM = VM 1
#
# For Task 1
# r1 = 0.47697973255735693 ,r2 = 0.9427416574340969
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.47697973255735693 * (15.0 - 15.0) + 1.4962 * 0.9427416574340969 * (15.0 - 15.0)
# New Velocity =  3.649
# Since New Velocity Is Positive , New Assigned VM = VM 0
#
# For Task 2
# r1 = 0.7534751250593859 ,r2 = 0.8534479505691046
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.7534751250593859 * (15.0 - 15.0) + 1.4962 * 0.8534479505691046 * (15.0 - 15.0)
# New Velocity =  3.649
# Since New Velocity Is Positive , New Assigned VM = VM 0
#
#
# After Iteration 2, Best Makespan = 15.0 is of Particle 2
#
# Starting Iteration 3 ,Now For Each Particle
# Before Iteration 3, Best Makespan = 15.0 is of Particle 2
# Particle 0
# Task 0(0) : VM 0  ,Execution Time  (300/20) = 15.0
# Task 1(0) : VM 1  ,Execution Time  (100/20) = 5.0
# Task 2(3) : VM 1  ,Execution Time  (100/20) = 5.0
# Current Fitness =  15.0
# Particle Personal Best =  15.0
# Global Best Fitness =  15.0
# For Task 0
# r1 = 0.5382205676102315 ,r2 = 0.7346340607563577
# New Velocity = 0.7298 * 300 / 20 + 1.4962 * 0.5382205676102315 * (15.0 - 15.0) + 1.4962 * 0.7346340607563577 * (15.0 - 15.0)
# New Velocity =  10.947
# Since New Velocity Is Positive , New Assigned VM = VM 1
#
# For Task 1
# r1 = 0.4882294775502505 ,r2 = 0.2729353117632566
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.4882294775502505 * (15.0 - 15.0) + 1.4962 * 0.2729353117632566 * (15.0 - 15.0)
# New Velocity =  3.649
# Since New Velocity Is Positive , New Assigned VM = VM 0
#
# For Task 2
# r1 = 0.02902481994671524 ,r2 = 0.33612954369838244
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.02902481994671524 * (15.0 - 15.0) + 1.4962 * 0.33612954369838244 * (15.0 - 15.0)
# New Velocity =  3.649
# Since New Velocity Is Positive , New Assigned VM = VM 0
#
#
# Particle 1
# Task 0(0) : VM 1  ,Execution Time  (300/20) = 15.0
# Task 1(0) : VM 1  ,Execution Time  (100/20) = 5.0
# Task 2(3) : VM 0  ,Execution Time  (100/20) = 5.0
# Current Fitness =  20.0
# Particle Personal Best =  20.0
# Global Best Fitness =  15.0
# For Task 0
# r1 = 0.7241813776272887 ,r2 = 0.8405056630625586
# New Velocity = 0.7298 * 300 / 20 + 1.4962 * 0.7241813776272887 * (20.0 - 20.0) + 1.4962 * 0.8405056630625586 * (15.0 - 20.0)
# New Velocity =  4.659177134628998
# Since New Velocity Is Positive , New Assigned VM = VM 0
#
# For Task 1
# r1 = 0.9807219775189232 ,r2 = 0.5341236295325044
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.9807219775189232 * (20.0 - 20.0) + 1.4962 * 0.5341236295325044 * (15.0 - 20.0)
# New Velocity =  -0.3467788725326648
# Since New Velocity Is Negative There is No Change
#
# For Task 2
# r1 = 0.9069288625867683 ,r2 = 0.5918927756279109
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.9069288625867683 * (20.0 - 20.0) + 1.4962 * 0.5918927756279109 * (15.0 - 20.0)
# New Velocity =  -0.7789498544724012
# Since New Velocity Is Negative There is No Change
#
#
# Particle 2
# Task 0(0) : VM 1  ,Execution Time  (300/20) = 15.0
# Task 1(0) : VM 0  ,Execution Time  (100/20) = 5.0
# Task 2(3) : VM 0  ,Execution Time  (100/20) = 5.0
# Current Fitness =  15.0
# Particle Personal Best =  15.0
# Global Best Fitness =  15.0
# For Task 0
# r1 = 0.6629997568361613 ,r2 = 0.08394746216200022
# New Velocity = 0.7298 * 300 / 20 + 1.4962 * 0.6629997568361613 * (15.0 - 15.0) + 1.4962 * 0.08394746216200022 * (15.0 - 15.0)
# New Velocity =  10.947
# Since New Velocity Is Positive , New Assigned VM = VM 0
#
# For Task 1
# r1 = 0.13569948723056424 ,r2 = 0.4616984440515117
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.13569948723056424 * (15.0 - 15.0) + 1.4962 * 0.4616984440515117 * (15.0 - 15.0)
# New Velocity =  3.649
# Since New Velocity Is Positive , New Assigned VM = VM 1
#
# For Task 2
# r1 = 0.2601563139193047 ,r2 = 0.32735266694173426
# New Velocity = 0.7298 * 100 / 20 + 1.4962 * 0.2601563139193047 * (15.0 - 15.0) + 1.4962 * 0.32735266694173426 * (15.0 - 15.0)
# New Velocity =  3.649
# Since New Velocity Is Positive , New Assigned VM = VM 1
#
#
# After Iteration 3, Best Makespan = 15.0 is of Particle 2
